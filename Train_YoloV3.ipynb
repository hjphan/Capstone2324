# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Sat Feb  3 13:17:32 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.23                 Driver Version: 551.23         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 Ti   WDDM  |   00000000:2B:00.0  On |                  N/A |
# | 42%   40C    P0             78W /  310W |    1047MiB /   8192MiB |      4%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# **1) Clone the Darknet**

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15833, done.
# remote: Total 15833 (delta 0), reused 0 (delta 0), pack-reused 15833
# Receiving objects: 100% (15833/15833), 14.39 MiB | 17.17 MiB/s, done.
# Resolving deltas: 100% (10666/10666), done.

# %% [markdown]
# **2) Compile Darknet using Nvidia GPU**

# %%
# %cd darknet
# %pwd
# Out:
# 'C:\\Users\\admin\\projects\\testproj04\\darknet'

# %%
# change makefile to have GPU and OPENCV enabled
#%cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# 'C:\\Users\\admin\\projects\\testproj04\\darknet'

# %% [markdown]
# **3) Configure Darknet network for training YOLO V3**

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %% [markdown]
# classes = #
#
# ---
#
#
# max_batches = classes * 2000
#
# ---
#
#
# filters = (classes + 5) * 3
#
# ---
# steps = max_batches * 0.8, max_batches * 0.9
# ---

# %%
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 6000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=3@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=3@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=3@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=24@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=24@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=24@' cfg/yolov3_training.cfg
# !sed -i '22 s@steps=400000,450000@steps=4800,5400@' cfg/yolov3_training.cfg

# %%
# Create folder on google drive so that we can save there the weights
# !mkdir weights

# %%
# !cp ../classesv1.txt data/obj.names
# Out:
# 'C:\\Users\\admin\\projects\\testproj04\\darknet'

# %%
#!echo -e 'classes= 3\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = weights' > data/obj.data
# !cp ../createobjdata.py createobjdata.py
# !python ../createobjdata.py
# Out:
# 'C:\\Users\\admin\\projects\\testproj04\\darknet'

# %%
# !cd data\obj
# Out:
# C:\Users\admin\projects\testproj04\darknet\data
# C:\Users\admin\miniconda3\envs\labelimg\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# C:\Users\admin\projects\testproj04\darknet

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-02-03 13:24:29--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: 'darknet53.conv.74'
#
#      0K .......... .......... .......... .......... ..........  0%  361K 7m19s
#     50K .......... .......... .......... .......... ..........  0%  726K 5m29s
#    100K .......... .......... .......... .......... ..........  0%  724K 4m52s
#    150K .......... .......... .......... .......... ..........  0%  724K 4m34s
#    200K .......... .......... .......... .......... ..........  0% 91.9M 3m39s
#    250K .......... .......... .......... .......... ..........  0%  723K 3m39s
#    300K .......... .......... .......... .......... ..........  0% 54.8M 3m8s
#    350K .......... .......... .......... .......... ..........  0%  734K 3m12s
# ...

# %% [markdown]
# **4) Extract Images**
#
# The images need to be inside a zip archive called "images.zip" and they need to be inside the folder "yolov3" on Google Drive

# %%
#!wget --auth-no-challenge --no-check-certificate github.com/hjphan/Capstone2324/releases/download/testing1/images.zip
#!unzip images.zip -d data/obj
# Out:
# --2024-02-06 16:06:18--  http://github.com/hjphan/Capstone2324/releases/download/testing1/images.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/hjphan/Capstone2324/releases/download/testing1/images.zip [following]
# --2024-02-06 16:06:18--  https://github.com/hjphan/Capstone2324/releases/download/testing1/images.zip
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !unzip images.zip -d data/obj
# Out:
# Archive:  images.zip
#   inflating: data/obj/image_1.jpg
#   inflating: data/obj/image_1.txt
#   inflating: data/obj/image_10.jpg
#   inflating: data/obj/image_10.txt
#   inflating: data/obj/image_100.jpg
#   inflating: data/obj/image_100.txt
#   inflating: data/obj/image_101.jpg
#   inflating: data/obj/image_101.txt
#   inflating: data/obj/image_102.jpg
#   inflating: data/obj/image_102.txt
#   inflating: data/obj/image_103.jpg
#   inflating: data/obj/image_103.txt
#   inflating: data/obj/image_104.jpg
#   inflating: data/obj/image_104.txt
#   inflating: data/obj/image_105.jpg
#   inflating: data/obj/image_105.txt
#   inflating: data/obj/image_106.jpg
#   inflating: data/obj/image_106.txt
#   inflating: data/obj/image_107.jpg
#   inflating: data/obj/image_107.txt
#   inflating: data/obj/image_108.jpg
#   inflating: data/obj/image_108.txt
#   inflating: data/obj/image_109.jpg
#   inflating: data/obj/image_109.txt
#   inflating: data/obj/image_11.jpg
# ...

# %%
# !cp ../createtrain.py createtrain.py
# !python createtrain.py
# Out:
# ['data/obj\\image_1.jpg', 'data/obj\\image_10.jpg', 'data/obj\\image_100.jpg', 'data/obj\\image_101.jpg', 'data/obj\\image_102.jpg', 'data/obj\\image_103.jpg', 'data/obj\\image_104.jpg', 'data/obj\\image_105.jpg', 'data/obj\\image_106.jpg', 'data/obj\\image_107.jpg', 'data/obj\\image_108.jpg', 'data/obj\\image_109.jpg', 'data/obj\\image_11.jpg', 'data/obj\\image_110.jpg', 'data/obj\\image_111.jpg', 'data/obj\\image_112.jpg', 'data/obj\\image_113.jpg', 'data/obj\\image_114.jpg', 'data/obj\\image_115.jpg', 'data/obj\\image_116.jpg', 'data/obj\\image_117.jpg', 'data/obj\\image_118.jpg', 'data/obj\\image_119.jpg', 'data/obj\\image_12.jpg', 'data/obj\\image_120.jpg', 'data/obj\\image_121.jpg', 'data/obj\\image_122.jpg', 'data/obj\\image_123.jpg', 'data/obj\\image_124.jpg', 'data/obj\\image_125.jpg', 'data/obj\\image_126.jpg', 'data/obj\\image_127.jpg', 'data/obj\\image_128.jpg', 'data/obj\\image_129.jpg', 'data/obj\\image_13.jpg', 'data/obj\\image_130.jpg', 'data/obj\\image_131.jpg', 'dat
# ...

# %%
# !cp build\darknet\x64\pthreadVC2.dll pthreadVC2.dll

# %% [markdown]
# **6) Start the training**

# %%
# Start the training
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# !darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
